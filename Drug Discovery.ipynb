# %%
import pandas as pd
import numpy as np
from chembl_webresource_client.new_client import new_client
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#target search
target = new_client.target
target_query = target.search("coronavirus")
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
# ...

# %%
single_protein_ids = (targets.target_chembl_id[4],
                      targets.target_chembl_id[6],
                      targets.target_chembl_id[7])

# %%
single_protein_ids
# Out:
# ('CHEMBL3927', 'CHEMBL5118', 'CHEMBL4523582')

# %%
#bioactivity for coronavirus 3C-like proteinase
activity = new_client.activity
res = activity.filter(target_chembl_id = single_protein_ids[0]).filter(standard_type = "IC50")
"""
ic50 value measure of the potency of a substnace in inhibiting specific
biological function by 50%
"""
# Out:
# '\nic50 value measure of the potency of a substnace in inhibiting specific\nbiological function by 50%\n'

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None      1480935                  []    CHEMBL829584
# 1             None      1480936                  []    CHEMBL829584
# 2             None      1481061                  []    CHEMBL830868
#
#                                    assay_description assay_type  \
# 0  In vitro inhibitory concentration against SARS...          B
# 1  In vitro inhibitory concentration against SARS...          B
# 2  In vitro inhibitory concentration against SARS...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ...   target_organism                     target_pref_name target_tax_id  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Standard value is potency, lower number the more potent, reflective
# of the concentration of drug to get 50% performance

# %%
df.to_csv('D:/Documents/Projects/Bioactivity/bioactivity_data.csv', index = False)

# %%
#df without missing values
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %%
#Labeling compounds as active, inactive, or intermediate
#ic50 < 1000nM active, >10000nM inactive, 
bioactivity_class = []
for i in df2.standard_value:
    if float(i) > 10000:
        bioactivity_class.append("inactive")
    elif float(i) < 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %%
df2.molecule_chembl_id
# Out:
# 0       CHEMBL187579
# 1       CHEMBL188487
# 2       CHEMBL185698
# 3       CHEMBL426082
# 4       CHEMBL187717
#            ...
# 128    CHEMBL2146517
# 129     CHEMBL187460
# 130     CHEMBL363535
# 131     CHEMBL227075
# 132      CHEMBL45830
# Name: molecule_chembl_id, Length: 133, dtype: object

# %%
#iterate id, smiles, standard values to list
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]

# %%
df4 = pd.concat([df3,pd.Series(bioactivity_class)], axis = 1)

# %%
df4.to_csv('D:/Documents/Projects/Bioactivity/bioactivity_preprocessed_data.csv', index = False)

# %% [markdown]
# <h1>Lipinski descriptors (Absorption, Distribtuion, Metabolism, Excretion)
# <h4><br>Rule:
# <br><ol>
#     <li>Molecular weight < 500 Dalton
#     <li>Octanol-water partition coefficient (LogP)<5
#     <li>Hydrogen Bond donors <5
#     <li>Hydrogen bond acceptors < 10
#                                     </ol>

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i = i+1     
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df.canonical_smiles)

# %%
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
df4.rename(columns = {0:'bioactivity_class'}, inplace = True)

# %%
df4
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value bioactivity_data
# 0           7200.0     intermediate
# ...

# %%
df_combined = pd.concat([df4,df_lipinski], axis = 1)

# %%
df_combined
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value bioactivity_data       MW     LogP  NumHDonors  \
# ...

# %% [markdown]
# Convert IC50 to pIC50 for normalization

# %%
sns.histplot((df_final.pIC50))
# Out:
# <AxesSubplot:xlabel='pIC50', ylabel='Count'>

# %%
mdata = df_combined['standard_value'].apply(pd.to_numeric)
sns.histplot(mdata)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-66-5867f129734c> in <module>
#       1 mdata = df_combined['standard_value'].apply(pd.to_numeric)
# ----> 2 sns.histplot(mdata)
#
# D:\anaconda3\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421     if p.univariate:
#    1422
# -> 1423         p.plot_univariate_histogram(
#    1424             multiple=multiple,
#    1425             element=element,
#
# ...

# %%
def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %%
df_combined.standard_value = df_combined.standard_value.apply(pd.to_numeric)
df_combined.standard_value.describe()
# Out:
# count    1.330000e+02
# mean     8.017926e+12
# std      3.344888e+13
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      3.311311e+14
# Name: standard_value, dtype: float64

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000: #value capped to avoid negative log values
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)
        
    return x

# %%
df_norm = norm_value(df_combined)
df_norm
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_data       MW     LogP  NumHDonors  NumHAcceptors  \
# ...

# %%
df_norm.standard_value_norm.describe()
# Out:
# count    1.330000e+02
# mean     2.110164e+07
# std      4.089714e+07
# min      5.000000e+01
# 25%      1.070000e+04
# 50%      2.350000e+04
# 75%      3.000000e+05
# max      1.000000e+08
# Name: standard_value_norm, dtype: float64

# %%
df_final = pIC50(df_norm)
df_final.describe()
# Out:
#                MW        LogP  NumHDonors  NumHAcceptors       pIC50
# count  133.000000  133.000000  133.000000     133.000000  133.000000
# mean   376.392692    3.908219    0.909774       5.248120    4.060148
# std     87.221623    1.385540    0.882993       2.072204    1.783762
# min    204.185000   -0.055400    0.000000       2.000000    1.000000
# 25%    296.366000    3.220320    0.000000       3.000000    3.522879
# 50%    369.515000    3.769900    1.000000       5.000000    4.628932
# 75%    437.437000    4.667120    2.000000       6.000000    4.970616
# max    588.635000    7.051540    3.000000      12.000000    7.301030

# %%
df_2class = df_final[df_final.bioactivity_class != "intermediate"]
df_2class
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 5         CHEMBL365134            O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21
# 7         CHEMBL190743             O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21
# 8         CHEMBL365469            O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_data       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %% [markdown]
# # Chemical Space Analysis: Lipinski Descriptors

# %% [markdown]
# Frequency of Bioactivity Classes (inactive, active)

# %%
plt.figure(figsize = (5.5,5.5))

sns.countplot(x = df_2class.bioactivity_class, edgecolor = "black")

plt.xlabel('Bioactivity Class', fontsize = 15, fontweight = 'bold')
plt.ylabel('Frequency', fontsize = 15, fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Scatter Plot of MW versus LogP

# %%
plt.figure(figsize=(5.5,5.5))

sns.scatterplot(x = 'MW', y = 'LogP', data = df_2class, 
                hue = "bioactivity_data", size = 'pIC50', edgecolor = 'black',
               alpha = .8)

plt.xlabel("MW", fontsize = 14, fontweight = 'bold')
plt.ylabel("LogP", fontsize = 14, fontweight = 'bold')
plt.legend(bbox_to_anchor= (1.5,1), loc = 1, borderaxespad = 0)

# %% [markdown]
# pIC50

# %%
plt.figure(figsize = (5.5,5.5))

sns.boxplot(data = df_2class, x = "bioactivity_data", y = 'pIC50')

plt.xlabel("Bioactivity Class", fontsize = 14, fontweight = 'bold')
plt.ylabel("pIC50 Values", fontsize = 14, fontweight = 'bold')
# Out:
# Text(0, 0.5, 'pIC50 Values')

# %% [markdown]
# # Statistical Analysis: Mann Whitney U test

# %%
def mannwhitney(descriptor, verbose = False):
    from numpy.random import seed
    from numpy.random import randn
    from scipy.stats import mannwhitneyu

    # seed the random number generator
    seed(1)

    # actives and inactives
    selection = [descriptor, 'bioactivity_data']
    df = df_2class[selection]
    active = df[df.bioactivity_data == 'active']
    active = active[descriptor]

    selection = [descriptor, 'bioactivity_data']
    df = df_2class[selection]
    inactive = df[df.bioactivity_data == 'inactive']
    inactive = inactive[descriptor]

    # compare samples
    stat, p = mannwhitneyu(active, inactive)
    #print('Statistics=%.3f, p=%.3f' % (stat, p))
    
    # interpret
    alpha = 0.05
    if p > alpha:
        interpretation = 'Same distribution (fail to reject H0)'
    else:
        interpretation = 'Different distribution (reject H0)'
  
    results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
    filename = 'mannwhitneyu_' + descriptor + '.csv'
    results.to_csv(filename)

    return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics             p  alpha  \
# 0      pIC50         0.0  1.729014e-10   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)

# %%
df_2class.columns
# Out:
# Index(['molecule_chembl_id', 'canonical_smiles', 'bioactivity_data', 'MW',
#        'LogP', 'NumHDonors', 'NumHAcceptors', 'pIC50'],
#       dtype='object')

# %% [markdown]
# MW

# %%
plt.figure(figsize = (5.5,5.5))

sns.boxplot(data = df_2class, x = "bioactivity_data", y = 'MW')

plt.xlabel("Bioactivity Class", fontsize = 14, fontweight = 'bold')
plt.ylabel("MW", fontsize = 14, fontweight = 'bold')
# Out:
# Text(0, 0.5, 'MW')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics         p  alpha                      Interpretation
# 0         MW       404.5  0.001666   0.05  Different distribution (reject H0)

# %% [markdown]
# LogP

# %%
plt.figure(figsize = (5.5,5.5))

sns.boxplot(data = df_2class, x = "bioactivity_data", y = 'LogP')

plt.xlabel("Bioactivity Class", fontsize = 14, fontweight = 'bold')
plt.ylabel("LogP Values", fontsize = 14, fontweight = 'bold')
# Out:
# Text(0, 0.5, 'LogP Values')

# %%
mannwhitney("LogP")
# Out:
#   Descriptor  Statistics         p  alpha  \
# 0       LogP       705.5  0.315229   0.05
#
#                           Interpretation
# 0  Same distribution (fail to reject H0)

# %% [markdown]
# NumHDonors

# %%
plt.figure(figsize = (5.5,5.5))

sns.boxplot(data = df_2class, x = "bioactivity_data", y = 'NumHDonors')

plt.xlabel("Bioactivity Class", fontsize = 14, fontweight = 'bold')
plt.ylabel("Number H Donors", fontsize = 14, fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Number H Donors')

# %%
mannwhitney("NumHDonors")
# Out:
#    Descriptor  Statistics        p  alpha                      Interpretation
# 0  NumHDonors       298.5  0.00003   0.05  Different distribution (reject H0)

# %% [markdown]
# NumHAcceptors

# %%
plt.figure(figsize = (5.5,5.5))

sns.boxplot(data = df_2class, x = "bioactivity_data", y = 'NumHAcceptors')

plt.xlabel("Bioactivity Class", fontsize = 14, fontweight = 'bold')
plt.ylabel("Number H Acceptors", fontsize = 14, fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Number H Acceptors')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics         p  alpha  \
# 0  NumHAcceptors       412.5  0.001817   0.05
#
#                        Interpretation
# 0  Different distribution (reject H0)
